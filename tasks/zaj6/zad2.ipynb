# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Wprowadzenie

# %% [markdown]
# Dane są zasadniczo te same co ostatnim razem, ale pochodzą z innego źródła. Mają też trochę inny format.
#
# Zasadnicze zadanie polega na zebraniu całych danych z pliku XLS (oba arkusze!), a następnie sformatowaniu ich do jednolitej postaci. Następnie należy te wyniki połączyć z wynikami z poprzedniego zadania.
#
# Dane są w pliku: "data-cl.xls".
#
# Załaduj dane do ramki pandas z jednego arkusza:

# %%
xls = pd.ExcelFile('data-cl.xls')

data1 = xls.parse('Sheet3', header=1)
data1.rename(columns={'Unnamed: 1': 'Rok', 'Nr:Tyg: ': 'Stacja'}, inplace=True)
data1['Rok'].fillna(method='ffill', inplace=True)
data1.drop('7Be ', 1, inplace=True)

data1_m = pd.melt(data1, id_vars=['Rok', 'Stacja'], var_name='Tyg', value_name='value')
data1_m['param'] = '7Be'

data2 = xls.parse('Sheet4', header=1)
data2.rename(columns={'Unnamed: 1': 'Rok', 'Nr:Tyg: ': 'Stacja'}, inplace=True)
data2['Rok'].fillna(method='ffill', inplace=True)
data2.drop('40K', 1, inplace=True)

data2_m = pd.melt(data2, id_vars=['Rok', 'Stacja'], var_name='Tyg', value_name='value')
data2_m['param'] = '40K'

data1_m
# Out:
#       Rok    Stacja Tyg  value param
# 0    2008  Stacja A   1    NaN   7Be
# 1    2008  Stacja B   1    NaN   7Be
# 2    2008  Stacja C   1    NaN   7Be
# 3    2009  Stacja A   1    NaN   7Be
# 4    2009  Stacja B   1    NaN   7Be
# 5    2009  Stacja C   1    NaN   7Be
# 6    2009  Stacja D   1    NaN   7Be
# 7    2010  Stacja A   1    358   7Be
# 8    2010  Stacja B   1    239   7Be
# 9    2010  Stacja C   1    231   7Be
# 10   2010  Stacja D   1    205   7Be
# 11   2010  Stacja E   1    NaN   7Be
# 12   2011  Stacja A   1    148   7Be
# 13   2011  Stacja B   1    177   7Be
# 14   2011  Stacja C   1    399   7Be
# 15   2011  Stacja D   1    297   7Be
# 16   2011  Stacja E   1    165   7Be
# 17   2008  Stacja A   2    NaN   7Be
# 18   2008  Stacja B   2    NaN   7Be
# 19   2008  Stacja C   2    NaN   7Be
# 20   2009  Stacja A   2    NaN   7Be
# 21   2009  Stacja B   2    NaN   7Be
# 22   2009  Stacja C   2    NaN   7Be
# 23   2009  Stacja D   2    NaN   7Be
# 24   2010  Stacja A   2    286   7Be
# 25   2010  Stacja B   2    157   7Be
# 26   2010  Stacja C   2    347   7Be
# 27   2010  Stacja D   2    162   7Be
# 28   2010  Stacja E   2    NaN   7Be
# 29   2011  Stacja A   2    429   7Be
# ..    ...       ...  ..    ...   ...
# 854  2009  Stacja B  51    380   7Be
# 855  2009  Stacja C  51    123   7Be
# 856  2009  Stacja D  51    173   7Be
# 857  2010  Stacja A  51    393   7Be
# 858  2010  Stacja B  51    179   7Be
# 859  2010  Stacja C  51    292   7Be
# 860  2010  Stacja D  51    267   7Be
# 861  2010  Stacja E  51    327   7Be
# 862  2011  Stacja A  51    NaN   7Be
# 863  2011  Stacja B  51    190   7Be
# 864  2011  Stacja C  51    406   7Be
# 865  2011  Stacja D  51    188   7Be
# 866  2011  Stacja E  51    161   7Be
# 867  2008  Stacja A  52    400   7Be
# 868  2008  Stacja B  52    378   7Be
# 869  2008  Stacja C  52    364   7Be
# 870  2009  Stacja A  52    NaN   7Be
# 871  2009  Stacja B  52    376   7Be
# 872  2009  Stacja C  52    170   7Be
# 873  2009  Stacja D  52    248   7Be
# 874  2010  Stacja A  52    231   7Be
# 875  2010  Stacja B  52    390   7Be
# 876  2010  Stacja C  52    135   7Be
# 877  2010  Stacja D  52    119   7Be
# 878  2010  Stacja E  52    308   7Be
# 879  2011  Stacja A  52    171   7Be
# 880  2011  Stacja B  52    359   7Be
# 881  2011  Stacja C  52    303   7Be
# 882  2011  Stacja D  52    330   7Be
# 883  2011  Stacja E  52    190   7Be
#
# [884 rows x 5 columns]

# %% [markdown]
# Jak zauważyłeś/aś dane dane mają dziwną strukturę, W wierszach mamy pomiar w kolejnych tygodniach dla poszczególnych stacji i lat.
#
# Na razie celem jest przekształcenie tych danyh na tabelkę o strukturze zawierającej kolumny: Data, Rodzaj Radionuklidu, Stacja, Wartość.
#
# Kolejność przekształceń jest taka (może wpadniecie na lepszą):
#
# * Na początek porządek w danych. Należy usunąć puste rzędy na górze, wyrzucić kolumnę w której jest tylko 7Be, nadać kolumnie z rokiem nazwę Rok, oraz kolumnie ze stacją nazwę Stacja.
# * Za pomocą funkcji pd.melt(...) dokonać unpivotowania danych
# * Z Roku i tygodnia wyznaczyć datę (jak w ostatnim ćwiczeniu).

# %%
from datetime import date, timedelta
def week_start_date(year, week, dow=0):    
    """
    :param int year: Numer roku
    :param int week: Numer tygodnia w roku 
    :param int dow: Funkcja ta zwraca datę, zwróci datę dnia o indeksie dow, zero oznacza poniedziałek, jeden wtorek itp. 
    """
    # http://stackoverflow.com/a/1287862/7918
    d = date(year, 1, 1)    
    delta_days = d.isoweekday() - 1
    delta_weeks = week
    if year == d.isocalendar()[0]:
        delta_weeks -= 1
    delta = timedelta(days=-delta_days+dow, weeks=delta_weeks)
    return d + delta

# %%
#dates1 = [week_start_date(int(y), int(w)) for y, w in zip(data1_m['Rok'], data1_m['Tyg'])]
#dates2 = [week_start_date(int(y), int(w)) for y, w in zip(data2_m['Rok'], data2_m['Tyg'])]

#data1_m.set_index([pd.DatetimeIndex(dates1), data1_m['Stacja']], inplace=True)
#data2_m.set_index([pd.DatetimeIndex(dates2), data2_m['Stacja']], inplace=True)

#data1_m.drop(['Rok', 'Tyg'], 1, inplace=True)
#data2_m.drop(['Rok', 'Tyg'], 1, inplace=True)

#data1_m[]

# %%
data1_m
# Out:
#       Rok    Stacja Tyg  value param
# 0    2008  Stacja A   1    NaN   7Be
# 1    2008  Stacja B   1    NaN   7Be
# 2    2008  Stacja C   1    NaN   7Be
# 3    2009  Stacja A   1    NaN   7Be
# 4    2009  Stacja B   1    NaN   7Be
# 5    2009  Stacja C   1    NaN   7Be
# 6    2009  Stacja D   1    NaN   7Be
# 7    2010  Stacja A   1    358   7Be
# 8    2010  Stacja B   1    239   7Be
# 9    2010  Stacja C   1    231   7Be
# 10   2010  Stacja D   1    205   7Be
# 11   2010  Stacja E   1    NaN   7Be
# 12   2011  Stacja A   1    148   7Be
# 13   2011  Stacja B   1    177   7Be
# 14   2011  Stacja C   1    399   7Be
# 15   2011  Stacja D   1    297   7Be
# 16   2011  Stacja E   1    165   7Be
# 17   2008  Stacja A   2    NaN   7Be
# 18   2008  Stacja B   2    NaN   7Be
# 19   2008  Stacja C   2    NaN   7Be
# 20   2009  Stacja A   2    NaN   7Be
# 21   2009  Stacja B   2    NaN   7Be
# 22   2009  Stacja C   2    NaN   7Be
# 23   2009  Stacja D   2    NaN   7Be
# 24   2010  Stacja A   2    286   7Be
# 25   2010  Stacja B   2    157   7Be
# 26   2010  Stacja C   2    347   7Be
# 27   2010  Stacja D   2    162   7Be
# 28   2010  Stacja E   2    NaN   7Be
# 29   2011  Stacja A   2    429   7Be
# ..    ...       ...  ..    ...   ...
# 854  2009  Stacja B  51    380   7Be
# 855  2009  Stacja C  51    123   7Be
# 856  2009  Stacja D  51    173   7Be
# 857  2010  Stacja A  51    393   7Be
# 858  2010  Stacja B  51    179   7Be
# 859  2010  Stacja C  51    292   7Be
# 860  2010  Stacja D  51    267   7Be
# 861  2010  Stacja E  51    327   7Be
# 862  2011  Stacja A  51    NaN   7Be
# 863  2011  Stacja B  51    190   7Be
# 864  2011  Stacja C  51    406   7Be
# 865  2011  Stacja D  51    188   7Be
# 866  2011  Stacja E  51    161   7Be
# 867  2008  Stacja A  52    400   7Be
# 868  2008  Stacja B  52    378   7Be
# 869  2008  Stacja C  52    364   7Be
# 870  2009  Stacja A  52    NaN   7Be
# 871  2009  Stacja B  52    376   7Be
# 872  2009  Stacja C  52    170   7Be
# 873  2009  Stacja D  52    248   7Be
# 874  2010  Stacja A  52    231   7Be
# 875  2010  Stacja B  52    390   7Be
# 876  2010  Stacja C  52    135   7Be
# 877  2010  Stacja D  52    119   7Be
# 878  2010  Stacja E  52    308   7Be
# 879  2011  Stacja A  52    171   7Be
# 880  2011  Stacja B  52    359   7Be
# 881  2011  Stacja C  52    303   7Be
# 882  2011  Stacja D  52    330   7Be
# 883  2011  Stacja E  52    190   7Be
#
# [884 rows x 5 columns]

# %% [markdown]
# ### Pobranie danych z drugiego skoroszytu

# %% [markdown]
# Tak samo pobierz dane z drugiego skoroszytu (zawiera on inny radionuklid)

# %% [markdown]
# ### Doklejenie wyników

# %% [markdown]
# Pobierz wyniki z zadania 1 i sformatuj je do takiej samej postaci (powiedzmy że pochodzą one ze stacji o nazwie: "Stacja Hor"), następnie połącz ramki razem

# %%
store = pd.HDFStore('store.h5')

data = store['data']
data['Stacja'] = 'Stacja Hor'
data.drop(['Data'], 1, inplace=True)

data_m = pd.melt(data, id_vars=['Rok', 'Tyg', 'Stacja'], var_name='param', value_name='value')

full = pd.concat([data_m, data1_m, data2_m])

dates = [week_start_date(int(y), int(w)) for y, w in zip(full['Rok'], full['Tyg'])]

full_i = full.set_index([pd.DatetimeIndex(dates), full['Stacja'], full['param']], verify_integrity=True)

full_i['Data'] = dates
full_i.sort_index(inplace=True)

#pd.options.display.max_rows = 10000
#full_i.loc['2010-01-11']

full_i
#full_i.index.names[0] = 'Data'
# Out:
#                               Rok      Stacja Tyg  param  value        Data
#            Stacja     param
#                       40K    2014  Stacja Hor  50    40K    NaN  2014-12-08
#                       7Be    2014  Stacja Hor  50    7Be    NaN  2014-12-08
#                       Dust   2014  Stacja Hor  50   Dust    NaN  2014-12-08
# 2014-12-15 Stacja Hor 134Cs  2014  Stacja Hor  51  134Cs    NaN  2014-12-15
#                       137Cs  2014  Stacja Hor  51  137Cs    NaN  2014-12-15
#                       210Pb  2014  Stacja Hor  51  210Pb    NaN  2014-12-15
#                       22Na   2014  Stacja Hor  51   22Na    NaN  2014-12-15
#                       40K    2014  Stacja Hor  51    40K    NaN  2014-12-15
#                       7Be    2014  Stacja Hor  51    7Be    NaN  2014-12-15
#                       Dust   2014  Stacja Hor  51   Dust    NaN  2014-12-15
# 2014-12-22 Stacja Hor 134Cs  2014  Stacja Hor  52  134Cs    NaN  2014-12-22
#                       137Cs  2014  Stacja Hor  52  137Cs    NaN  2014-12-22
#                       210Pb  2014  Stacja Hor  52  210Pb    NaN  2014-12-22
#                       22Na   2014  Stacja Hor  52   22Na    NaN  2014-12-22
#                       40K    2014  Stacja Hor  52    40K    NaN  2014-12-22
#                       7Be    2014  Stacja Hor  52    7Be    NaN  2014-12-22
#                       Dust   2014  Stacja Hor  52   Dust    NaN  2014-12-22
#
# [3588 rows x 6 columns]

# %% [markdown]
# ### Pivoting pełnych danych

# %% [markdown]
# Teraz skonstruuj tabelkę zawierającą takie kolumny:
#
# * Data
# * Dla każdej kombinacji Stacji i parametru kolumnę z poziomem zanieczyszczenia

# %%
piv = full_i.pivot(index='Data', columns=['Stacja', 'param'], values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6d0b2484e66e> in <module>()
# ----> 1 piv = full_i.pivot(index='Data', columns=['Stacja', 'param'], values='value')
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    3390         """
#    3391         from pandas.core.reshape import pivot
# -> 3392         return pivot(self, index=index, columns=columns, values=values)
#    3393
#    3394     def stack(self, level=-1, dropna=True):
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/reshape.py in pivot(self, index, columns, values)
#     368         indexed = Series(self[values].values,
#     369                          index=MultiIndex.from_arrays([self[index],
# --> 370                                                        self[columns]]))
#     371         return indexed.unstack(columns)
#     372
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/index.py in from_arrays(cls, arrays, sortorder, names)
#    3262             return Index(arrays[0], name=name)
#    3263
# -> 3264         cats = [Categorical.from_array(arr) for arr in arrays]
#    3265         levels = [c.categories for c in cats]
#    3266         labels = [c.codes for c in cats]
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/index.py in <listcomp>(.0)
#    3262             return Index(arrays[0], name=name)
#    3263
# -> 3264         cats = [Categorical.from_array(arr) for arr in arrays]
#    3265         levels = [c.categories for c in cats]
#    3266         labels = [c.codes for c in cats]
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/categorical.py in from_array(cls, data, **kwargs)
#     328             the unique values of `data`.
#     329         """
# --> 330         return Categorical(data, **kwargs)
#     331
#     332     @classmethod
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/categorical.py in __init__(self, values, categories, ordered, name, fastpath, levels)
#     224
#     225         # sanitize input
# --> 226         if com.is_categorical_dtype(values):
#     227
#     228             # we are either a Series or a Categorical
#
# /home/dk/.virtualenvs/nasypy-new/lib/python3.4/site-packages/pandas/core/generic.py in __nonzero__(self)
#     690         raise ValueError("The truth value of a {0} is ambiguous. "
#     691                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 692                          .format(self.__class__.__name__))
#     693
#     694     __bool__ = __nonzero__
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### Wyniki

# %% [markdown]
# Wyświetl wyniki w ładnym wykresie :)
